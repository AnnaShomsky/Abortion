# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
health=pd.read_csv("health_and_populaiton.csv")
health.head()
# Out:
#        Country Code ContinentCode  Year  Population size in millions  \
# 0  Afghanistan  AFG            AS  1960                         9.00
# 1  Afghanistan  AFG            AS  1961                         9.17
# 2  Afghanistan  AFG            AS  1962                         9.35
# 3  Afghanistan  AFG            AS  1963                         9.54
# 4  Afghanistan  AFG            AS  1964                         9.74
#
#    Health spending per capita  Health spending as percent of GDP  \
# 0                         NaN                                NaN
# 1                         NaN                                NaN
# 2                         NaN                                NaN
# 3                         NaN                                NaN
# 4                         NaN                                NaN
#
#    Life expectancy in years  \
# 0                     32.45
# 1                     32.96
# 2                     33.47
# 3                     33.97
# ...

# %%
abortion=pd.read_csv("Global Abortion Incidence Dataset.csv")
abortion.head()
# Out:
#    country  iso  yearstart  yearend                       region  \
# 0  Albania  8.0       1990     1990  Europe and Northern America
# 1  Albania  8.0       1991     1991  Europe and Northern America
# 2  Albania  8.0       1992     1992  Europe and Northern America
# 3  Albania  8.0       1993     1993  Europe and Northern America
# 4  Albania  8.0       1994     1994  Europe and Northern America
#
#          subregion  numberofabortions  abortionrate  perc_p_ending_in_a  \
# 0  Southern Europe            17400.0           NaN                 NaN
# 1  Southern Europe            20300.0           NaN                 NaN
# 2  Southern Europe            18700.0           NaN                 NaN
# 3  Southern Europe            25100.0           NaN                 NaN
# 4  Southern Europe            31622.0           NaN                 NaN
#
#   spontaneous             datatype    datasource    complete  \
# 0          No  Official Statistics  Henshaw 2001  Incomplete
# ...

# %%
abortion.columns
# Out:
# Index(['country', 'iso', 'yearstart', 'yearend', 'region', 'subregion',
#        'numberofabortions', 'abortionrate', 'perc_p_ending_in_a',
#        'spontaneous', 'datatype', 'datasource', 'complete', 'classification',
#        'modelused', 'marriedonly', 'notes'],
#       dtype='object')

# %%
legal= pd.read_csv("abortionlegality.csv")
legal.head()
# Out:
#        country                            legality
# 0  Afghanistan              To save a woman's life
# 1      Albania                      No restriction
# 2      Algeria  To preserve physical/mental health
# 3      Andorra               Prohibited altogether
# 4       Angola               Prohibited altogether

# %%
legal.loc[(legal["legality"]=="No restriction")].count()
# Out:
# country     57
# legality    57
# dtype: int64

# %%
legal.loc[(legal["legality"]=="To save a woman's life")].count()
# Out:
# country     37
# legality    37
# dtype: int64

# %%
legal.loc[(legal["legality"]=="Prohibited altogether")].count()
# Out:
# country     25
# legality    25
# dtype: int64

# %%
legal.legality.unique()
# Out:
# array(["To save a woman's life", 'No restriction',
#        'To preserve physical/mental health', 'Prohibited altogether',
#        'To preserve physical health',
#        'To preserve health/on socioeconomic grounds'], dtype=object)

# %%
legal.loc[(legal["legality"]=="To preserve physical/mental health")].count()
# Out:
# country     23
# legality    23
# dtype: int64

# %%
legal.loc[(legal["legality"]=="To preserve physical health")].count()
# Out:
# country     36
# legality    36
# dtype: int64

# %%
legal.loc[(legal["legality"]=="To preserve health/on socioeconomic grounds")].count()
# Out:
# country     13
# legality    13
# dtype: int64

# %%
types= legal[["legality"]].groupby(by = "legality").legality.count()
types.head()
# Out:
# legality
# No restriction                                 57
# Prohibited altogether                          25
# To preserve health/on socioeconomic grounds    13
# To preserve physical health                    36
# To preserve physical/mental health             23
# Name: legality, dtype: int64

# %%
types.plot(kind= "bar", title= "abortion restirctions worldwide")
# Out:
# <AxesSubplot:title={'center':'abortion restirctions worldwide'}, xlabel='legality'>

# %%
types2=pd.DataFrame(types)
types2.head()
types3= types2.rename(columns={"legality":"count"})
types3.head()
# Out:
#                                              count
# legality
# No restriction                                  57
# Prohibited altogether                           25
# To preserve health/on socioeconomic grounds     13
# To preserve physical health                     36
# To preserve physical/mental health              23

# %%
types4= types3.sort_values(by="count")
types4.head()
# Out:
#                                              count
# legality
# To preserve health/on socioeconomic grounds     13
# To preserve physical/mental health              23
# Prohibited altogether                           25
# To preserve physical health                     36
# To save a woman's life                          37

# %%
types4.plot(kind= "bar", title= "abortion restirctions worldwide")
# Out:
# <AxesSubplot:title={'center':'abortion restirctions worldwide'}, xlabel='legality'>

# %%
population= pd.read_csv("populaiton country by year.csv")
population.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965  ...         2012         2013         2014         2015  \
# ...

# %%
health.tail()
# Out:
#         Country Code ContinentCode  Year  Population size in millions  \
# 12178  Zimbabwe  ZWE            AF  2017                        14.24
# 12179  Zimbabwe  ZWE            AF  2018                        14.44
# 12180  Zimbabwe  ZWE            AF  2019                        14.65
# 12181  Zimbabwe  ZWE            AF  2020                        14.86
# 12182  Zimbabwe  ZWE            AF  2021                          NaN
#
#        Health spending per capita  Health spending as percent of GDP  \
# 12178                      115.65                               7.47
# 12179                      141.37                               8.68
# 12180                      103.03                               7.70
# 12181                         NaN                                NaN
# 12182                         NaN                                NaN
#
#        Life expectancy in years  \
# 12178                     60.81
# 12179                     61.19
# ...

# %%
health_2019 = health.loc[(health["Year"]==2019)]
health_2019.head()
# Out:
#          Country Code ContinentCode  Year  Population size in millions  \
# 59   Afghanistan  AFG            AS  2019                        38.04
# 121      Albania  ALB            EU  2019                         2.85
# 183      Algeria  DZA            AF  2019                        43.05
# 245      Andorra  AND            EU  2019                         0.08
# 306       Angola  AGO            AF  2019                        31.83
#
#      Health spending per capita  Health spending as percent of GDP  \
# 59                        65.81                              13.24
# 121                         NaN                                NaN
# 183                      248.21                               6.24
# 245                     2744.19                               6.71
# 306                       71.33                               2.53
#
#      Life expectancy in years  \
# 59                      64.83
# 121                     78.57
# 183                     76.88
# ...

# %%
health_2018 = health.loc[(health["Year"]==2018)]
health_2018.head()
# Out:
#          Country Code ContinentCode  Year  Population size in millions  \
# 58   Afghanistan  AFG            AS  2018                        37.17
# 120      Albania  ALB            EU  2018                         2.87
# 182      Algeria  DZA            AF  2018                        42.23
# 244      Andorra  AND            EU  2018                         0.08
# 305       Angola  AGO            AF  2018                        30.81
#
#      Health spending per capita  Health spending as percent of GDP  \
# 58                        70.00                              14.13
# 120                      274.91                               5.23
# 182                      256.01                               6.16
# 244                     2821.80                               6.75
# 305                       87.31                               2.54
#
#      Life expectancy in years  \
# 58                      64.49
# 120                     78.46
# 182                     76.69
# ...

# %%
health_2019.columns
# Out:
# Index(['Country', 'Code', 'ContinentCode', 'Year',
#        'Population size in millions', 'Health spending per capita',
#        'Health spending as percent of GDP', 'Life expectancy in years',
#        'The number of crude births per 1000 people per year',
#        'Fertility rate births per woman',
#        'Prevalence of HIV percent of the population ages 15-49',
#        'Suicide mortality rate per 100000 population',
#        'Maternal mortality per 100000 live births',
#        'Neonates dying before 28 days of age per 1000 births',
#        'Infant deaths per 1000 live births',
#        'Deaths of children under five years of age per 1000 live births',
#        'Public spending on education percent of GDP',
#        'Cost of living index world average = 100',
#        'Happiness Index 0 (unhappy) - 10 (happy)',
#        'Human Development Index (0 - 1)', 'Women in parliament percent'],
#       dtype='object')

# %%
health_2019["population"]= health_2019["Population size in millions"]*1000000
health_2019.head()
# Out:
# /var/folders/bc/88y__jqx7s591njj3c2hmjn40000gn/T/ipykernel_72885/3304350194.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   health_2019["population"]= health_2019["Population size in millions"]*1000000
#          Country Code ContinentCode  Year  Population size in millions  \
# 59   Afghanistan  AFG            AS  2019                        38.04
# 121      Albania  ALB            EU  2019                         2.85
# 183      Algeria  DZA            AF  2019                        43.05
# 245      Andorra  AND            EU  2019                         0.08
# 306       Angola  AGO            AF  2019                        31.83
#
#      Health spending per capita  Health spending as percent of GDP  \
# ...

# %%
abortion_2018= abortion.loc[(abortion["yearstart"]==2018)]
abortion_2018.head()
# Out:
#       country    iso  yearstart  yearend                       region  \
# 568     China  156.0       2018     2018   East and Southeastern Asia
# 901   Denmark  208.0       2018     2018  Europe and Northern America
# 1056  Finland  246.0       2018     2018  Europe and Northern America
# 1273  Germany  276.0       2018     2018  Europe and Northern America
# 2230   Norway  578.0       2018     2018  Europe and Northern America
#
#             subregion  numberofabortions  abortionrate  perc_p_ending_in_a  \
# 568      Eastern Asia          9740000.0           NaN                 NaN
# 901   Northern Europe            14284.0           NaN                 NaN
# 1056  Northern Europe             8602.0           NaN                 NaN
# 1273   Western Europe            99905.0           NaN                 NaN
# 2230  Northern Europe            12216.0           NaN                 NaN
#
#      spontaneous             datatype  \
# 568           No  Official Statistics
# ...

# %%
health_2018["population"]= health_2018["Population size in millions"]*1000000
health_2018.head()
# Out:
# /var/folders/bc/88y__jqx7s591njj3c2hmjn40000gn/T/ipykernel_72885/2417968910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   health_2018["population"]= health_2018["Population size in millions"]*1000000
#          Country Code ContinentCode  Year  Population size in millions  \
# 58   Afghanistan  AFG            AS  2018                        37.17
# 120      Albania  ALB            EU  2018                         2.87
# 182      Algeria  DZA            AF  2018                        42.23
# 244      Andorra  AND            EU  2018                         0.08
# 305       Angola  AGO            AF  2018                        30.81
#
#      Health spending per capita  Health spending as percent of GDP  \
# ...

# %%
health_abortion= health_2018.merge(abortion_2018, left_on="Year", right_on= "yearstart")
health_abortion.head()
# Out:
#        Country Code ContinentCode  Year  Population size in millions  \
# 0  Afghanistan  AFG            AS  2018                        37.17
# 1  Afghanistan  AFG            AS  2018                        37.17
# 2  Afghanistan  AFG            AS  2018                        37.17
# 3  Afghanistan  AFG            AS  2018                        37.17
# 4  Afghanistan  AFG            AS  2018                        37.17
#
#    Health spending per capita  Health spending as percent of GDP  \
# 0                        70.0                              14.13
# 1                        70.0                              14.13
# 2                        70.0                              14.13
# 3                        70.0                              14.13
# 4                        70.0                              14.13
#
#    Life expectancy in years  \
# 0                     64.49
# 1                     64.49
# 2                     64.49
# 3                     64.49
# ...

# %%
health_abortion_legal= health_abortion.merge(legal, left_on = "Country", right_on = "country")
health_abortion_legal.head()
# Out:
#        Country Code ContinentCode  Year  Population size in millions  \
# 0  Afghanistan  AFG            AS  2018                        37.17
# 1  Afghanistan  AFG            AS  2018                        37.17
# 2  Afghanistan  AFG            AS  2018                        37.17
# 3  Afghanistan  AFG            AS  2018                        37.17
# 4  Afghanistan  AFG            AS  2018                        37.17
#
#    Health spending per capita  Health spending as percent of GDP  \
# 0                        70.0                              14.13
# 1                        70.0                              14.13
# 2                        70.0                              14.13
# 3                        70.0                              14.13
# 4                        70.0                              14.13
#
#    Life expectancy in years  \
# 0                     64.49
# 1                     64.49
# 2                     64.49
# 3                     64.49
# ...

# %%
health_abortion_legal.columns
# Out:
# Index(['Country', 'Code', 'ContinentCode', 'Year',
#        'Population size in millions', 'Health spending per capita',
#        'Health spending as percent of GDP', 'Life expectancy in years',
#        'The number of crude births per 1000 people per year',
#        'Fertility rate births per woman',
#        'Prevalence of HIV percent of the population ages 15-49',
#        'Suicide mortality rate per 100000 population',
#        'Maternal mortality per 100000 live births',
#        'Neonates dying before 28 days of age per 1000 births',
#        'Infant deaths per 1000 live births',
#        'Deaths of children under five years of age per 1000 live births',
#        'Public spending on education percent of GDP',
#        'Cost of living index world average = 100',
#        'Happiness Index 0 (unhappy) - 10 (happy)',
#        'Human Development Index (0 - 1)', 'Women in parliament percent',
#        'population', 'country_x', 'iso', 'yearstart', 'yearend', 'region',
# ...

# %%
health_abortion_legal["Country"].count()
# Out:
# 1086

# %%
health_abortion_legal2= health_abortion_legal.drop_duplicates(subset=["Country"], keep='first', ignore_index=True)
health_abortion_legal2["Country"].count()
# Out:
# 181

# %%
health_abortion_legal2["abortion_code"]= np.where(health_abortion_legal2["legality"] == "No restriction", 1, 
                                                 np.where(health_abortion_legal2["legality"] == "Prohibited altogether",3,2))
# Out:
# /var/folders/bc/88y__jqx7s591njj3c2hmjn40000gn/T/ipykernel_72885/772323008.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   health_abortion_legal2["abortion_code"]= np.where(health_abortion_legal2["legality"] == "No restriction", 1,

# %%
abortion_numeric= health_abortion_legal2[["Population size in millions", "Health spending per capita", "Health spending as percent of GDP", "Life expectancy in years", "The number of crude births per 1000 people per year", "Fertility rate births per woman","Prevalence of HIV percent of the population ages 15-49", "Suicide mortality rate per 100000 population","Maternal mortality per 100000 live births","Deaths of children under five years of age per 1000 live births","Neonates dying before 28 days of age per 1000 births","Infant deaths per 1000 live births","Deaths of children under five years of age per 1000 live births","Public spending on education percent of GDP","Cost of living index world average = 100","Happiness Index 0 (unhappy) - 10 (happy)",
                                          'Human Development Index (0 - 1)','Women in parliament percent','numberofabortions','abortionrate','perc_p_ending_in_a', 'abortion_code' ]]

abortion_numeric.head()
# Out:
#    Population size in millions  Health spending per capita  \
# 0                        37.17                       70.00
# 1                         2.87                      274.91
# 2                        42.23                      256.01
# 3                         0.08                     2821.80
# 4                        30.81                       87.31
#
#    Health spending as percent of GDP  Life expectancy in years  \
# 0                              14.13                     64.49
# 1                               5.23                     78.46
# 2                               6.16                     76.69
# 3                               6.75                       NaN
# 4                               2.54                     60.78
#
#    The number of crude births per 1000 people per year  \
# 0                                              32.49
# 1                                              11.78
# 2                                              24.28
# ...

# %%
df_pearson = abortion_numeric.corr(method='pearson')
sns.set(rc = {'figure.figsize':(20, 12)})
go=sns.heatmap(df_pearson, annot=True, cmap="YlGnBu")

ax = go

# %%
deaths1= health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==1)]["Deaths of children under five years of age per 1000 live births"].mean()
print("number of deaths per 1000 births in places with no aboriton restrictions: " + str(deaths1))
# Out:
# number of deaths per 1000 births in places with no aboriton restrictions: 10.407407407407407

# %%
deaths2= health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==2)]["Deaths of children under five years of age per 1000 live births"].mean()

print("number of deaths per 1000 births in places with some aboriton restrictions: " + str(deaths2))
# Out:
# number of deaths per 1000 births in places with some aboriton restrictions: 36.59

# %%
deaths3= health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==3)]["Deaths of children under five years of age per 1000 live births"].mean()
print("number of deaths per 1000 births in places that prohibit abortions: " + str(deaths3))
# Out:
# number of deaths per 1000 births in places that prohibit abortions: 31.17391304347826

# %%
neonate_1=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==1)]["Neonates dying before 28 days of age per 1000 births"].mean()
print("neonatal deaths per 1000 births in places with no aboriton restrictions: " + str(neonate_1))

neonate_2=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==2)]["Neonates dying before 28 days of age per 1000 births"].mean()
print("neonatal deaths per 1000 births in places with some aboriton restrictions: " + str(neonate_2))

neonate_3=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==3)]["Neonates dying before 28 days of age per 1000 births"].mean()
print("neonatal deaths per 1000 births in places that prhohibit abortion: " + str(neonate_3))
# Out:
# neonatal deaths per 1000 births in places with no aboriton restrictions: 5.851851851851852
# neonatal deaths per 1000 births in places with some aboriton restrictions: 16.13
# neonatal deaths per 1000 births in places that prhohibit abortion: 15.347826086956522

# %%
suicide_1=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==1)]["Suicide mortality rate per 100000 population"].mean()
print("suicide rate  with no aboriton restrictions: " + str(suicide_1))

suicide_2=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==2)]["Suicide mortality rate per 100000 population"].mean()
print("suicide rate  with some aboriton restrictions: " + str(suicide_2))

suicide_3=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==3)]["Suicide mortality rate per 100000 population"].mean()
print("suicide rate  with abortion prohibited: " + str(suicide_3))
# Out:
# suicide rate  with no aboriton restrictions: 13.012962962962964
# suicide rate  with some aboriton restrictions: 8.11855670103093
# suicide rate  with abortion prohibited: 7.1450000000000005

# %%
infant_1=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==1)]["Infant deaths per 1000 live births"].mean()
print("infant death rate per 1000 live births with no aboriton restrictions: " + str(infant_1))

infant_2=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==2)]["Infant deaths per 1000 live births"].mean()
print("infant death rate per 1000 live births with some aboriton restrictions: " + str(infant_2))


infant_3=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==3)]["Infant deaths per 1000 live births"].mean()
print("infant death rate per 1000 live births where aboriton prohibited: " + str(infant_3))
# Out:
# infant death rate per 1000 live births with no aboriton restrictions: 8.851851851851851
# infant death rate per 1000 live births with some aboriton restrictions: 27.13
# infant death rate per 1000 live births where aboriton prohibited: 24.043478260869566

# %%
le_1=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==1)]["Life expectancy in years"].mean()
print("life expectancy in places with no aboriton restrictions: " + str(le_1))
le_2=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==2)]["Life expectancy in years"].mean()
print("life expectancy in places with some aboriton restrictions: " + str(le_2))
le_3=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==3)]["Life expectancy in years"].mean()
print("life expectancy in places where aboriton is prohibited: " + str(le_3))
# Out:
# life expectancy in places with no aboriton restrictions: 76.67481481481482
# life expectancy in places with some aboriton restrictions: 70.73919191919195
# life expectancy in places where aboriton is prohibited: 69.70250000000001

# %%
hs_1=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==1)]["Health spending as percent of GDP"].mean()
print("health spending as percent GDP in places with no aboriton restrictions: " + str(hs_1))
hs_2=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==2)]["Health spending as percent of GDP"].mean()
print("health spending as percent GDP in places with some aboriton restrictions: " + str(hs_2))
hs_3=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==3)]["Health spending as percent of GDP"].mean()
print("health spending as percent GDP in places where abortion is prohibited: " + str(hs_3))
# Out:
# health spending as percent GDP in places with no aboriton restrictions: 7.301509433962264
# health spending as percent GDP in places with some aboriton restrictions: 6.070104166666664
# health spending as percent GDP in places where abortion is prohibited: 5.7239130434782615

# %%
wp_1=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==1)]["Women in parliament percent"].mean()
print("percent women in parliament in places with no aboriton restrictions: " + str(wp_1))
wp_2=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==2)]["Women in parliament percent"].mean()
print("percent women in parliament in places with some aboriton restrictions: " + str(wp_2))
wp_3=  health_abortion_legal2.loc[(health_abortion_legal2["abortion_code"]==3)]["Women in parliament percent"].mean()
print("percent women in parliament in places where abortion is prohibited: " + str(wp_3))
# Out:
# percent women in parliament in places with no aboriton restrictions: 26.465000000000003
# percent women in parliament in places with some aboriton restrictions: 19.948600000000003
# percent women in parliament in places where abortion is prohibited: 21.722727272727273

# %%
infant_rate= {"LEGALITY": ["No abortion restrictions", "some abortion restirctions", "abortion prohibited"], "infant death rate per 1000 live births": [infant_1, infant_2, infant_3]}
infant_rate_df= pd.DataFrame(data= infant_rate)
infant_rate_df
infant_rate_df= infant_rate_df.set_index("LEGALITY")

# %%
plt.rcParams["figure.figsize"] = (12,8)


infant_rate_df.plot(kind= "bar", title= "Average Infant Death Rate per 1000 Live Births Relative to Abortion Restrictions")

plt.xticks(rotation=0)
plt.ylabel("INFANT  DEATH  RATE", fontdict=None)
plt.rcParams['xtick.color'] = "Black"
plt.rcParams['axes.labelcolor'] = "Blue"

plt.rc('font', size=15)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=15, )    # fontsize of the x and y labels
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=12)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
# plt.rcParams.update({'font.size': 50})

# %%
life_rate= {"LEGALITY": ["No abortion restrictions", "some abortion restirctions", "abortion prohibited"], "infant death rate per 1000 live births": [le_1, le_2, le_3]}
life_rate_df= pd.DataFrame(data= life_rate)

life_rate_df= life_rate_df.set_index("LEGALITY")
life_rate_df
# Out:
#                             infant death rate per 1000 live births
# LEGALITY
# No abortion restrictions                                 76.674815
# some abortion restirctions                               70.739192
# abortion prohibited                                      69.702500

# %%
plt.rcParams["figure.figsize"] = (12,8)


life_rate_df.plot(kind= "bar", title= "Average Life Expectancy Relative to Abortion Restrictions")

plt.xticks(rotation=0)
plt.ylabel("LIFE EXPECTANCY", fontdict=None)
plt.rcParams['xtick.color'] = "Black"
plt.rcParams['axes.labelcolor'] = "Blue"

plt.rc('font', size=15)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=15, )    # fontsize of the x and y labels
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=12)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
# plt.rcParams.update({'font.size': 50})

# %%
neonate= {"LEGALITY": ["No abortion restrictions", "some abortion restirctions", "abortion prohibited"], "neonatal deaths per 1000 live births": [neonate_1, neonate_2, neonate_3]}
neonate_df= pd.DataFrame(data= neonate)

neonate_df= neonate_df.set_index("LEGALITY")
neonate_df
# Out:
#                             neonatal deaths per 1000 live births
# LEGALITY
# No abortion restrictions                                5.851852
# some abortion restirctions                             16.130000
# abortion prohibited                                    15.347826

# %%
plt.rcParams["figure.figsize"] = (12,8)


neonate_df.plot(kind= "bar", title= "Neonatal Deaths per 1000 Live Births Relative to Abortion Restrictions")

plt.xticks(rotation=0)
plt.ylabel("NEONATAL DEATHS", fontdict=None)
plt.rcParams['xtick.color'] = "Black"
plt.rcParams['axes.labelcolor'] = "Blue"

plt.rc('font', size=15)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=15, )    # fontsize of the x and y labels
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=12)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
# plt.rcParams.update({'font.size': 50})

# %%
#Happiness Index 0 (unhappy) - 10 (happy)

# %%
health["Maternal mortality per 100000 live births"].unique()
# Out:
# array([     nan, 1.45e+03, 1.39e+03, 1.30e+03, 1.24e+03, 1.18e+03,
#        1.14e+03, 1.12e+03, 1.09e+03, 1.03e+03, 9.93e+02, 9.54e+02,
#        9.05e+02, 8.58e+02, 8.10e+02, 7.86e+02, 7.01e+02, 6.73e+02,
#        6.38e+02, 2.30e+01, 2.10e+01, 1.80e+01, 2.20e+01, 1.90e+01,
#        2.00e+01, 1.70e+01, 1.60e+01, 1.50e+01, 1.61e+02, 1.55e+02,
#        1.48e+02, 1.45e+02, 1.34e+02, 1.27e+02, 1.22e+02, 1.19e+02,
#        1.17e+02, 1.15e+02, 1.16e+02, 1.14e+02, 1.13e+02, 1.12e+02,
#        8.27e+02, 7.66e+02, 6.90e+02, 6.28e+02, 5.74e+02, 5.19e+02,
#        4.73e+02, 4.31e+02, 3.95e+02, 3.59e+02, 3.26e+02, 3.00e+02,
#        2.81e+02, 2.69e+02, 2.58e+02, 2.51e+02, 2.46e+02, 2.41e+02,
#        4.40e+01, 4.30e+01, 4.10e+01, 4.00e+01, 4.60e+01, 4.80e+01,
#        5.00e+01, 4.50e+01, 4.20e+01, 6.60e+01, 6.70e+01, 6.50e+01,
#        6.10e+01, 5.90e+01, 5.70e+01, 5.60e+01, 5.30e+01, 5.10e+01,
#        4.70e+01, 3.90e+01, 3.80e+01, 3.60e+01, 3.50e+01, 3.20e+01,
# ...

# %%
health.loc[(health["Maternal mortality per 100000 live births"]).notnull()]
# Out:
#            Country Code ContinentCode  Year  Population size in millions  \
# 40     Afghanistan  AFG            AS  2000                        20.78
# 41     Afghanistan  AFG            AS  2001                        21.61
# 42     Afghanistan  AFG            AS  2002                        22.60
# 43     Afghanistan  AFG            AS  2003                        23.68
# 44     Afghanistan  AFG            AS  2004                        24.73
# ...            ...  ...           ...   ...                          ...
# 12174     Zimbabwe  ZWE            AF  2013                        13.35
# 12175     Zimbabwe  ZWE            AF  2014                        13.59
# 12176     Zimbabwe  ZWE            AF  2015                        13.81
# 12177     Zimbabwe  ZWE            AF  2016                        14.03
# 12178     Zimbabwe  ZWE            AF  2017                        14.24
#
#        Health spending per capita  Health spending as percent of GDP  \
# ...

# %%
health_2017 = health.loc[(health["Year"]==2017)]
health_2017.loc[(health_2017["Maternal mortality per 100000 live births"]).notnull()]
# Out:
#                    Country Code ContinentCode  Year  \
# 57             Afghanistan  AFG            AS  2017
# 119                Albania  ALB            EU  2017
# 181                Algeria  DZA            AF  2017
# 304                 Angola  AGO            AF  2017
# 365    Antigua and Barbuda  ATG           NaN  2017
# ...                    ...  ...           ...   ...
# 11930            Venezuela  VEN            SA  2017
# 11992              Vietnam  VNM            AS  2017
# 12054                Yemen  YEM            AS  2017
# 12116               Zambia  ZMB            AF  2017
# 12178             Zimbabwe  ZWE            AF  2017
#
#        Population size in millions  Health spending per capita  \
# 57                           36.30                       65.71
# 119                           2.87                      226.28
# 181                          41.39                      258.06
# 304                          29.82                      114.33
# ...

# %%
health_abortion_legal_2017= health_2017.merge(legal, left_on = "Country", right_on = "country")
health_abortion_legal_2017.head()
# Out:
#        Country Code ContinentCode  Year  Population size in millions  \
# 0  Afghanistan  AFG            AS  2017                        36.30
# 1      Albania  ALB            EU  2017                         2.87
# 2      Algeria  DZA            AF  2017                        41.39
# 3      Andorra  AND            EU  2017                         0.08
# 4       Angola  AGO            AF  2017                        29.82
#
#    Health spending per capita  Health spending as percent of GDP  \
# 0                       65.71                              12.62
# 1                      226.28                               5.01
# 2                      258.06                               6.28
# 3                     2567.42                               6.59
# 4                      114.33                               2.79
#
#    Life expectancy in years  \
# 0                     64.13
# 1                     78.33
# 2                     76.50
# 3                       NaN
# ...

# %%
health_abortion_legal_2017["abortion_code"]= np.where(health_abortion_legal_2017["legality"] == "No restriction", 1, 
                                                 np.where(health_abortion_legal_2017["legality"] == "Prohibited altogether",3,2))

# %%
health_abortion_legal_2017_numeric= health_abortion_legal_2017[["Population size in millions", "Health spending per capita", "Health spending as percent of GDP", "Life expectancy in years", "The number of crude births per 1000 people per year", "Fertility rate births per woman","Prevalence of HIV percent of the population ages 15-49", "Suicide mortality rate per 100000 population","Maternal mortality per 100000 live births","Deaths of children under five years of age per 1000 live births","Neonates dying before 28 days of age per 1000 births","Infant deaths per 1000 live births","Deaths of children under five years of age per 1000 live births","Public spending on education percent of GDP","Cost of living index world average = 100","Happiness Index 0 (unhappy) - 10 (happy)",
                                          'Human Development Index (0 - 1)','Women in parliament percent', 'abortion_code' ]]

# %%
health_abortion_legal_2017_numeric_pearson = health_abortion_legal_2017_numeric.corr(method='pearson')
sns.set(rc = {'figure.figsize':(20, 12)})
go=sns.heatmap(health_abortion_legal_2017_numeric_pearson, annot=True, cmap="YlGnBu")

ax = go

# %%
health_abortion_legal_2017.columns
# Out:
# Index(['Country', 'Code', 'ContinentCode', 'Year',
#        'Population size in millions', 'Health spending per capita',
#        'Health spending as percent of GDP', 'Life expectancy in years',
#        'The number of crude births per 1000 people per year',
#        'Fertility rate births per woman',
#        'Prevalence of HIV percent of the population ages 15-49',
#        'Suicide mortality rate per 100000 population',
#        'Maternal mortality per 100000 live births',
#        'Neonates dying before 28 days of age per 1000 births',
#        'Infant deaths per 1000 live births',
#        'Deaths of children under five years of age per 1000 live births',
#        'Public spending on education percent of GDP',
#        'Cost of living index world average = 100',
#        'Happiness Index 0 (unhappy) - 10 (happy)',
#        'Human Development Index (0 - 1)', 'Women in parliament percent',
#        'country', 'legality', 'abortion_code'],
#       dtype='object')

# %%
maternal_deaths_1=  health_abortion_legal_2017.loc[(health_abortion_legal_2017["abortion_code"]==1)]["Maternal mortality per 100000 live births"].mean()
print("maternal deaths per 1000 live births in places with no aboriton restrictions: " + str(maternal_deaths_1))
                                                                                                     
maternal_deaths_2=  health_abortion_legal_2017.loc[(health_abortion_legal_2017["abortion_code"]==2)]["Maternal mortality per 100000 live births"].mean()
print("maternal deaths per 1000 live births in places with some aboriton restrictions: " + str(maternal_deaths_2))
                                                                                                     
maternal_deaths_3=  health_abortion_legal_2017.loc[(health_abortion_legal_2017["abortion_code"]==3)]["Maternal mortality per 100000 live births"].mean()
print("maternal deaths per 1000 live births in places where abortion is prohibited: " + str(maternal_deaths_3))
# Out:
# maternal deaths per 1000 live births in places with no aboriton restrictions: 26.48148148148148
# maternal deaths per 1000 live births in places with some aboriton restrictions: 215.4020618556701
# maternal deaths per 1000 live births in places where abortion is prohibited: 194.45

# %%
maternal_death= {"LEGALITY": ["No abortion restrictions", "some abortion restirctions", "abortion prohibited"], "maternal deaths per 1000 live births": [maternal_deaths_1, maternal_deaths_2, maternal_deaths_3]}
maternal_death_df= pd.DataFrame(data= maternal_death)

maternal_death_df= maternal_death_df.set_index("LEGALITY")
maternal_death_df
# Out:
#                             maternal deaths per 1000 live births
# LEGALITY
# No abortion restrictions                               26.481481
# some abortion restirctions                            215.402062
# abortion prohibited                                   194.450000

# %%
plt.rcParams["figure.figsize"] = (12,8)


maternal_death_df.plot(kind= "bar", title= "Maternal Deaths per 100,000 Live Births Relative to Abortion Restrictions")

plt.xticks(rotation=0)
plt.ylabel("MATERNAL DEATHS", fontdict=None)
plt.rcParams['xtick.color'] = "Black"
plt.rcParams['axes.labelcolor'] = "Blue"

plt.rc('font', size=15)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=15, )    # fontsize of the x and y labels
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=12)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title
# plt.rcParams.update({'font.size': 50})
